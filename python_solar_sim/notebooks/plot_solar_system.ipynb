# %%
import sys
sys.path.append('/home/connor/sol_sim/src/')

# %%
import importlib
import plot_files
importlib.reload(plot_files)
import utilities
import constants
importlib.reload(constants)
# Out:
# ['sol', 'mercury', 'venus', 'earth', 'mars']

# %%
bodies = list(utilities.parse_yaml(constants.YAML_PATH / "sol_system.yaml")['bodies'].keys())
bodies

# %%
importlib.reload(plot_files)
plot_files.plot_3d_body_motion(bodies)
# Out:
# No handles with labels found to put in legend.

# %%
importlib.reload(plot_files)
plot_files.plot_body_motion(bodies)
# Out:
# No handles with labels found to put in legend.
